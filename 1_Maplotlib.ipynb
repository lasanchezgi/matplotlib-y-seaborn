# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pyplot básico

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, color='red', marker='x')
plt.show()

# %%
plt.plot(x,y, 'rs-')
plt.show()

# %%
plt.plot(x,y, 'yD:')
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %%
plt.boxplot(y)
plt.show()

# %% [markdown]
# ## Subplot

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r*-')
plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.plot(y,x,'b--')
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'r--')
plt.plot(y,x,'b--')
plt.subplot(2,1,2)
plt.pie(y)
plt.show()

# %% [markdown]
# ## Método orientado a objetos

# %% [markdown]
# ```
# #Pyplot
# plt.figure(figsize=(9,7), dpi=100)
# plt.plot(time, velocity, 'g-')
# plt.plot(time, distance, 'b-')
# plt.ylabel('Distance and Velocity')
# plt.xlabel('Time')
# plt.grid(True)
#
# #Object oriented
# fig, ax1 = plt.subplots()
# ax1.set_ylabel('Distance(m)')
# ax1.set_xlabel('Time')
# ax1.plot(time, distance, 'blue')
#
# ax2 = ax1.twinx()
# ax2.set_ylabel('Velocity (m/s)')
# ax2.set_xlabel('Time')
# ax2.plot(time, velocity, 'green')
# fig.set_size_inches(7,5)
# fig.set_dpi(100)
#
# ```

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.5,0.9])
axes.plot(x,y,'b')
fig.show()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_4004\4018303986.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.9])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'b')
axes2.plot(y,x,'r')
axes2.set_facecolor('pink')
fig.show()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_4004\2735160425.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Subplots

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,'r')
axes[1].plot(y,x,'b')

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x,y,'r')
ax2.plot(y,x,'b')

# %%
fig, axes = plt.subplots(2, 4)
axes[0,0].plot(x, np.cos(x))
axes[0,1].plot(x, np.sin(x), 'r')
axes[0,2].plot(x, np.tan(x), 'y')
axes[0,3].plot(x, np.sinh(x), 'pink')
axes[1,0].plot(x, np.cosh(x))
axes[1,1].plot(x, np.tanh(x))
axes[1,2].plot(x, np.cos(x)**2)
axes[1,3].plot(x, np.cosh(x)**2)
fig.tight_layout()

# %% [markdown]
# ## Leyendas, etiquetas, títulos, tamaño

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5))

axes[0].set_title('Relacion X-Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].plot(x,y, label='$sin(x)$')
axes[0].legend()

axes[1].set_title('Relacion Y-X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
axes[1].plot(y,x, label='$sin(y)$')
axes[1].legend()

# %%
plt.plot(x,y, label = 'sin(x)')
plt.title('Grafica')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower left', bbox_to_anchor=(1,0.5))

# %% [markdown]
# ## Colores y estilos

# %%
x = np.linspace(0,5,11)

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('Solarize_Light2')

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x,x+1,'r--')
ax.plot(x,x+2,'b-')
ax.plot(x,x+3,'y.-')
ax.plot(x,x+4,'g:')
ax.plot(x,x+5,'pink')

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x,x+1, color='green', alpha=0.7, linestyle='-', marker='o')
ax.plot(x,x+2, color='blue', linewidth=8, linestyle='--', marker='x', markersize=15, markerfacecolor='#CCFFCC')
ax.plot(x,x+3, color='yellow', linewidth=4, linestyle='dashed', marker='v')
ax.plot(x,x+4, color='black', linewidth=4, linestyle=':', marker='P')
ax.plot(x,x+5, color='pink', linewidth=2, linestyle='-.', marker='*')

# %% [markdown]
# ## Bar plot

# %%
country = ['INDIA', 'JAPAN', 'MEXICO', 'COLOMBIA', 'GERMANY']
population = [1000,800,900,100,300]

# %%
plt.bar(country, population)
plt.show()

# %%
plt.bar(country, population, width=0.5, color=['red','blue'])
plt.xticks(np.arange(5), ('India', 'Japon', 'Mexico', 'colombia', 'Alemania'), rotation=45)
plt.show()

# %%
plt.barh(country, population)
plt.show()

# %% [markdown]
# ## Crea otro tipo de gráficas

# %%
data = np.random.randint(1,50,100)
data
# Out:
# array([ 7, 42, 31, 43, 30, 22, 42, 37, 35, 46, 37, 33, 17, 35, 44, 29, 30,
#         1, 21, 46,  7, 44, 18, 44, 42, 30, 46, 35, 34, 39, 32, 27,  6,  7,
#        41, 46, 23, 15, 16, 18, 11, 22, 16,  5, 24,  2, 19, 30, 39, 38, 24,
#        23, 22,  6, 37, 47, 45, 41,  7, 40, 40,  8, 32,  1, 38, 38, 24, 29,
#        12, 20, 45, 10, 28, 20, 40, 19, 27, 26, 16,  5, 42,  8,  5,  3, 16,
#        29, 34,  3, 26, 12, 23, 46, 17,  4, 32, 42, 39, 22, 12, 41])

# %%
plt.hist(data, bins=15, width=2.5, histtype='bar')
plt.show()

# %%
plt.hist(data, bins=15, histtype='step')
plt.show()

# %%
plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True)
plt.show()

# %%
data = np.append(data,200)
plt.boxplot(data, vert=False, patch_artist=True, notch=True)
plt.show()

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True, showfliers=False)
plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30*np.random.rand(N))**2
colors = np.random.rand(N)

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y, s=area, c=colors, marker='o', alpha=0.5)
plt.show()
