# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pyplot básico

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, color='red', marker='x')
plt.show()

# %%
plt.plot(x,y, 'rs-')
plt.show()

# %%
plt.plot(x,y, 'yD:')
plt.show()

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %%
plt.boxplot(y)
plt.show()

# %% [markdown]
# ## Subplot

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r*-')
plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.plot(y,x,'b--')
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'r--')
plt.plot(y,x,'b--')
plt.subplot(2,1,2)
plt.pie(y)
plt.show()

# %% [markdown]
# ## Método orientado a objetos

# %% [markdown]
# ```python
# #Pyplot
# plt.figure(figsize=(9,7), dpi=100)
# plt.plot(time, velocity, 'g-')
# plt.plot(time, distance, 'b-')
# plt.ylabel('Distance and Velocity')
# plt.xlabel('Time')
# plt.grid(True)
#
# #Object oriented
# fig, ax1 = plt.subplots()
# ax1.set_ylabel('Distance(m)')
# ax1.set_xlabel('Time')
# ax1.plot(time, distance, 'blue')
#
# ax2 = ax1.twinx()
# ax2.set_ylabel('Velocity (m/s)')
# ax2.set_xlabel('Time')
# ax2.plot(time, velocity, 'green')
# fig.set_size_inches(7,5)
# fig.set_dpi(100)
#
# ```

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.5,0.9])
axes.plot(x,y,'b')
fig.show()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2528\4018303986.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.9])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'b')
axes2.plot(y,x,'r')
axes2.set_facecolor('pink')
fig.show()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_2528\2735160425.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ## Subplots

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,'r')
axes[1].plot(y,x,'b')

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x,y,'r')
ax2.plot(y,x,'b')

# %%
fig, axes = plt.subplots(2, 4)
axes[0,0].plot(x, np.cos(x))
axes[0,1].plot(x, np.sin(x), 'r')
axes[0,2].plot(x, np.tan(x), 'y')
axes[0,3].plot(x, np.sinh(x), 'pink')
axes[1,0].plot(x, np.cosh(x))
axes[1,1].plot(x, np.tanh(x))
axes[1,2].plot(x, np.cos(x)**2)
axes[1,3].plot(x, np.cosh(x)**2)
fig.tight_layout()

# %% [markdown]
# ## Leyendas, etiquetas, títulos, tamaño

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5))

axes[0].set_title('Relacion X-Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].plot(x,y, label='$sin(x)$')
axes[0].legend()

axes[1].set_title('Relacion Y-X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
axes[1].plot(y,x, label='$sin(y)$')
axes[1].legend()

# %%
plt.plot(x,y, label = 'sin(x)')
plt.title('Grafica')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower left', bbox_to_anchor=(1,0.5))

# %% [markdown]
# ## Colores y estilos

# %%
x = np.linspace(0,5,11)

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('Solarize_Light2')

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x,x+1,'r--')
ax.plot(x,x+2,'b-')
ax.plot(x,x+3,'y.-')
ax.plot(x,x+4,'g:')
ax.plot(x,x+5,'pink')

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.plot(x,x+1, color='green', alpha=0.7, linestyle='-', marker='o')
ax.plot(x,x+2, color='blue', linewidth=8, linestyle='--', marker='x', markersize=15, markerfacecolor='#CCFFCC')
ax.plot(x,x+3, color='yellow', linewidth=4, linestyle='dashed', marker='v')
ax.plot(x,x+4, color='black', linewidth=4, linestyle=':', marker='P')
ax.plot(x,x+5, color='pink', linewidth=2, linestyle='-.', marker='*')

# %% [markdown]
# ## Bar plot

# %%
country = ['INDIA', 'JAPAN', 'MEXICO', 'COLOMBIA', 'GERMANY']
population = [1000,800,900,100,300]

# %%
plt.bar(country, population)
plt.show()

# %%
plt.bar(country, population, width=0.5, color=['red','blue'])
plt.xticks(np.arange(5), ('India', 'Japon', 'Mexico', 'colombia', 'Alemania'), rotation=45)
plt.show()

# %%
plt.barh(country, population)
plt.show()

# %% [markdown]
# ## Crea otro tipo de gráficas

# %%
data = np.random.randint(1,50,100)
data
# Out:
# array([45, 10,  9, 41, 31, 45, 19,  6, 18, 34, 32, 15, 18, 30, 47, 45, 22,
#         7, 49,  5, 47, 49, 30, 16, 26, 42, 36, 15, 30, 29, 16,  2, 30, 28,
#        13, 27, 22, 35, 11, 22, 23, 46, 14,  8, 48, 12, 39,  6, 46, 37, 32,
#         4, 41, 26, 15, 14, 42, 33, 28, 13, 13,  5,  4, 16, 21, 30, 17, 38,
#        33, 14, 42,  3, 17, 45, 28, 28, 45, 46,  5, 15, 18, 36,  9, 24, 15,
#        12, 21,  7, 13, 28, 40, 35, 25, 40,  2, 29, 17, 31, 44, 43])

# %%
plt.hist(data, bins=15, width=2.5, histtype='bar')
plt.show()

# %%
plt.hist(data, bins=15, histtype='step')
plt.show()

# %%
plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True)
plt.show()

# %%
data = np.append(data,200)
plt.boxplot(data, vert=False, patch_artist=True, notch=True)
plt.show()

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True, showfliers=False)
plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30*np.random.rand(N))**2
colors = np.random.rand(N)

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y, s=area, c=colors, marker='o', alpha=0.5)
plt.show()
